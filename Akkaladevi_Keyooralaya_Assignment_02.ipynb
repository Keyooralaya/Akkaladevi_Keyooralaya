# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Your code here

import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_imdb_reviews(movie_id, num_reviews=1000):
    base_url = f"https://www.imdb.com/title/{movie_id}/reviews"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    reviews = []
    for start in range(1, num_reviews+1, 10):
        url = f"{base_url}?start={start}"
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")
        review_containers = soup.find_all("div", class_="text show-more__control")
        for review in review_containers:
            reviews.append(review.text.strip())
    return reviews

# Movie ID for "Inception"
movie_id = "tt1375666"

# Scrape top 1000 user reviews
reviews = scrape_imdb_reviews(movie_id, num_reviews=1000)

# Convert data to DataFrame
df = pd.DataFrame({"Review": reviews})

# Save data to CSV
df.to_csv("inception_reviews.csv", index=False)

print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.

import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Load NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')

# Load the CSV file with the collected text data
df = pd.read_csv("inception_reviews.csv")

# Display the first few rows of the DataFrame
print("Original Data:")
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Original Data:
#                                               Review
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...

# %% [markdown]
# Remove noise, such as special characters and punctuations

# %%
df['clean_text'] = df['Review'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# Display the data after removing noise
print("\nData after removing noise:")
print(df.head())
# Out:
# Data after removing noise:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text
# 0  My 3rd time watching this movie Yet it still s...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream you feel th...
# 3  When I first watch this movie I was just shock...
# 4  The 20th Century had Casablanca Star Wars the ...

# %% [markdown]
# Remove numbers

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(r'\d+', '', x))

# Display the data after removing numbers
print("\nData after removing numbers:")
print(df.head())
# Out:
# Data after removing numbers:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text
# 0  My rd time watching this movie Yet it still st...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream you feel th...
# 3  When I first watch this movie I was just shock...
# 4  The th Century had Casablanca Star Wars the Go...

# %% [markdown]
# Remove stopwords by using the stopwords list.

# %%
stop_words = set(stopwords.words('english'))
df['clean_text'] = df['clean_text'].apply(lambda x: ' '.join(word for word in x.split() if word.lower() not in stop_words))

# Display the data after removing stopwords
print("\nData after removing stopwords:")
print(df.head())
# Out:
# Data after removing stopwords:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text
# 0  rd time watching movie Yet still stunned mind ...
# 1  get watch first time choose state mind careful...
# 2  wake good dream feel reality harsh wake bad dr...
# 3  first watch movie shocked twist Im gonna menti...
# 4  th Century Casablanca Star Wars Godfather Blad...

# %% [markdown]
# Lowercase all texts

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: x.lower())

# Display the data after lowercasing
print("\nData after lowercasing:")
print(df.head())
# Out:
# Data after lowercasing:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text
# 0  rd time watching movie yet still stunned mind ...
# 1  get watch first time choose state mind careful...
# 2  wake good dream feel reality harsh wake bad dr...
# 3  first watch movie shocked twist im gonna menti...
# 4  th century casablanca star wars godfather blad...

# %%
# Initialize stemming and lemmatization objects
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Stemming

# %%
df['stemmed_text'] = df['clean_text'].apply(lambda x: ' '.join(stemmer.stem(word) for word in x.split()))

# Display the data after stemming
print("\nData after stemming:")
print(df.head())
# Out:
# Data after stemming:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text  \
# 0  rd time watching movie yet still stunned mind ...
# 1  get watch first time choose state mind careful...
# 2  wake good dream feel reality harsh wake bad dr...
# 3  first watch movie shocked twist im gonna menti...
# 4  th century casablanca star wars godfather blad...
#
#                                         stemmed_text
# 0  rd time watch movi yet still stun mind kept en...
# 1  get watch first time choos state mind care fil...
# 2  wake good dream feel realiti harsh wake bad dr...
# 3  first watch movi shock twist im gonna mention ...
# 4  th centuri casablanca star war godfath blade r...

# %% [markdown]
# Lemmatization

# %%
df['lemmatized_text'] = df['clean_text'].apply(lambda x: ' '.join(lemmatizer.lemmatize(word) for word in x.split()))

# Display the data after lemmatization
print("\nData after lemmatization:")
print(df.head())
# Out:
# Data after lemmatization:
#                                               Review  \
# 0  My 3rd time watching this movie! Yet, it still...
# 1  You only get to watch this for the first time ...
# 2  When you wake up from a good dream, you feel t...
# 3  When I first watch this movie, I was just shoc...
# 4  The 20th Century had Casablanca, Star Wars, th...
#
#                                           clean_text  \
# 0  rd time watching movie yet still stunned mind ...
# 1  get watch first time choose state mind careful...
# 2  wake good dream feel reality harsh wake bad dr...
# 3  first watch movie shocked twist im gonna menti...
# 4  th century casablanca star wars godfather blad...
#
#                                         stemmed_text  \
# 0  rd time watch movi yet still stun mind kept en...
# 1  get watch first time choos state mind care fil...
# 2  wake good dream feel realiti harsh wake bad dr...
# 3  first watch movi shock twist im gonna mention ...
# 4  th centuri casablanca star war godfath blade r...
#
#                                      lemmatized_text
# 0  rd time watching movie yet still stunned mind ...
# 1  get watch first time choose state mind careful...
# 2  wake good dream feel reality harsh wake bad dr...
# 3  first watch movie shocked twist im gonna menti...
# 4  th century casablanca star war godfather blade...

# %%
# Save the cleaned data with new columns to CSV
df.to_csv("cleaned_inception_reviews.csv", index=False)

print("\nCleaned inception data saved successfully.")
# Out:
# Cleaned inception data saved successfully.

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
import pandas as pd
import nltk
import spacy

# Load NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Load SpaCy resources
nlp = spacy.load("en_core_web_sm")

# Load the cleaned data from the CSV file
df = pd.read_csv("cleaned_inception_reviews.csv")

# Define function for Parts of Speech (POS) tagging
def pos_tagging(text):
    pos_tags = nltk.pos_tag(nltk.word_tokenize(text))
    pos_counts = {"Noun": 0, "Verb": 0, "Adjective": 0, "Adverb": 0}
    for word, pos in pos_tags:
        if pos.startswith("N"):
            pos_counts["Noun"] += 1
        elif pos.startswith("V"):
            pos_counts["Verb"] += 1
        elif pos.startswith("J"):
            pos_counts["Adjective"] += 1
        elif pos.startswith("R"):
            pos_counts["Adverb"] += 1
    return pos_counts

# Define function for constituency parsing
def constituency_parsing(text):
    doc = nlp(text)
    constituency_trees = [sent._.parse_string for sent in doc.sents]
    return constituency_trees

# Define function for dependency parsing
def dependency_parsing(text):
    doc = nlp(text)
    dependency_trees = [(token.text, token.dep_, token.head.text) for sent in doc.sents for token in sent]
    return dependency_trees

# Define function for Named Entity Recognition (NER)
def ner(text):
    doc = nlp(text)
    entities = {}
    for ent in doc.ents:
        entity_type = ent.label_
        entity_text = ent.text
        if entity_type not in entities:
            entities[entity_type] = []
        entities[entity_type].append(entity_text)
    return entities

# Apply functions to each review
df['POS_Tagging'] = df['clean_text'].apply(pos_tagging)
df['Constituency_Parsing'] = df['clean_text'].apply(constituency_parsing)
df['Dependency_Parsing'] = df['clean_text'].apply(dependency_parsing)
df['NER'] = df['clean_text'].apply(ner)

# Save the DataFrame with analysis results to a new CSV file
df.to_csv("analysis_results.csv", index=False)

print("Analysis results saved to 'analysis_results.csv'")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Analysis results saved to 'analysis_results.csv'

# %%
import pandas as pd

# Load the analysis results from the CSV file
df = pd.read_csv("analysis_results.csv")

# Count the occurrences of each attribute value in the dataset
pos_counts = df['POS_Tagging'].apply(pd.Series).stack().value_counts()
constituency_counts = df['Constituency_Parsing'].apply(pd.Series).stack().value_counts()
dependency_counts = df['Dependency_Parsing'].apply(pd.Series).stack().value_counts()

# Display the count for each attribute
print("POS Tagging Counts:")
print(pos_counts)
print("\nConstituency Parsing Counts:")
print(constituency_counts)
print("\nDependency Parsing Counts:")
print(dependency_counts)
# Out:
# POS Tagging Counts:
# {'Noun': 297, 'Verb': 127, 'Adjective': 132, 'Adverb': 57}    100
# {'Noun': 180, 'Verb': 85, 'Adjective': 84, 'Adverb': 30}      100
# {'Noun': 145, 'Verb': 82, 'Adjective': 59, 'Adverb': 18}      100
# {'Noun': 72, 'Verb': 31, 'Adjective': 33, 'Adverb': 8}        100
# {'Noun': 90, 'Verb': 41, 'Adjective': 31, 'Adverb': 25}       100
# {'Noun': 152, 'Verb': 61, 'Adjective': 72, 'Adverb': 28}      100
# {'Noun': 136, 'Verb': 66, 'Adjective': 68, 'Adverb': 32}      100
# {'Noun': 35, 'Verb': 23, 'Adjective': 17, 'Adverb': 9}        100
# {'Noun': 152, 'Verb': 52, 'Adjective': 53, 'Adverb': 24}      100
# {'Noun': 101, 'Verb': 45, 'Adjective': 50, 'Adverb': 22}      100
# {'Noun': 81, 'Verb': 43, 'Adjective': 31, 'Adverb': 12}       100
# {'Noun': 66, 'Verb': 32, 'Adjective': 38, 'Adverb': 16}       100
# {'Noun': 115, 'Verb': 47, 'Adjective': 59, 'Adverb': 24}      100
# {'Noun': 21, 'Verb': 10, 'Adjective': 12, 'Adverb': 6}        100
# {'Noun': 262, 'Verb': 98, 'Adjective': 100, 'Adverb': 54}     100
# {'Noun': 3, 'Verb': 0, 'Adjective': 0, 'Adverb': 0}           100
# {'Noun': 82, 'Verb': 40, 'Adjective': 60, 'Adverb': 34}       100
# {'Noun': 25, 'Verb': 14, 'Adjective': 9, 'Adverb': 5}         100
# {'Noun': 127, 'Verb': 60, 'Adjective': 63, 'Adverb': 39}      100
# {'Noun': 34, 'Verb': 7, 'Adjective': 14, 'Adverb': 8}         100
# {'Noun': 114, 'Verb': 50, 'Adjective': 54, 'Adverb': 21}      100
# {'Noun': 16, 'Verb': 6, 'Adjective': 6, 'Adverb': 3}          100
# {'Noun': 41, 'Verb': 13, 'Adjective': 25, 'Adverb': 8}        100
# {'Noun': 11, 'Verb': 3, 'Adjective': 5, 'Adverb': 1}          100
# {'Noun': 49, 'Verb': 21, 'Adjective': 12, 'Adverb': 12}       100
# dtype: int64
#
# Constituency Parsing Counts:
# ['']                1900
# ['', '']             500
# ['', '', '', '']     100
# dtype: int64
#
# Dependency Parsing Counts:
# [('rd', 'compound', 'time'), ('time', 'nsubj', 'left'), ('watching', 'acl', 'time'), ('movie', 'dobj', 'watching'), ('yet', 'advmod', 'stunned'), ('still', 'advmod', 'stunned'), ('stunned', 'amod', 'mind'), ('mind', 'conj', 'time'), ('kept', 'acl', 'time'), ('enjoyed', 'xcomp', 'kept'), ('every', 'det', 'moment'), ('moment', 'npadvmod', 'kept'), ('left', 'ccomp', 'came'), ('many', 'amod', 'thoughts'), ('thoughts', 'dobj', 'left'), ('afterwardfor', 'prep', 'left'), ('someone', 'pobj', 'afterwardfor'), ('like', 'prep', 'someone'), ('who', 'nsubj', 'slept'), ('ve', 'aux', 'slept'), ('rarely', 'advmod', 'slept'), ('slept', 'relcl', 'someone'), ('without', 'prep', 'slept'), ('dream', 'pobj', 'without'), ('exciting', 'amod', 'dream'), ('watching', 'pcomp', 'without'), ('christopher', 'compound', 'nolan'), ('nolan', 'nsubj', 'illustrated'), ('illustrated', 'conj', 'left'), ('every', 'det', 'dream'), ('single', 'amod', 'dream'), ('characteristic', 'amod', 'dream'), ('dream', 'nmod', 'screen'), ('big', 'amod', 'screen'), ('screen', 'nsubj', 'believe'), ('done', 'acl', 'screen'), ('sophisticatedly', 'advmod', 'believe'), ('believe', 'ccomp', 'illustrated'), ('rumour', 'compound', 'nolan'), ('nolan', 'nsubj', 'spent'), ('spent', 'ccomp', 'believe'), ('years', 'dobj', 'spent'), ('finish', 'compound', 'inception'), ('script', 'compound', 'inception'), ('inception', 'compound', 'opinion'), ('opinion', 'dobj', 'spent'), ('far', 'advmod', 'greatest'), ('greatest', 'amod', 'career'), ('achievement', 'nmod', 'career'), ('brilliant', 'amod', 'career'), ('writerdirector', 'compound', 'career'), ('career', 'nsubj', 'jumped'), ('jumped', 'ccomp', 'believe'), ('conclusion', 'dobj', 'jumped'), ('making', 'acl', 'conclusion'), ('quick', 'amod', 'works'), ('benchmark', 'nmod', 'works'), ('nolans', 'nmod', 'works'), ('remarkable', 'amod', 'works'), ('works', 'dobj', 'making'), ('memento', 'nmod', 'history'), ('first', 'amod', 'history'), ('signature', 'nmod', 'history'), ('cinema', 'compound', 'history'), ('history', 'npadvmod', 'tremendous'), ('tremendous', 'nsubj', 'stayed'), ('stayed', 'amod', 'film'), ('mindbending', 'compound', 'film'), ('film', 'nsubj', 'reach'), ('i', 'nsubj', 'seen'), ('ve', 'aux', 'seen'), ('ever', 'advmod', 'seen'), ('seen', 'relcl', 'film'), ('overall', 'advmod', 'seen'), ('does', 'aux', 'reach'), ('nt', 'neg', 'reach'), ('reach', 'conj', 'left'), ('level', 'dobj', 'reach'), ('inceptionthe', 'det', 'prestige'), ('prestige', 'dobj', 'level'), ('highly', 'advmod', 'impressive'), ('impressive', 'amod', 'level'), ('somehow', 'advmod', 'have'), ('have', 'conj', 'left'), ('nt', 'neg', 'have'), ('able', 'advcl', 'left'), ('find', 'xcomp', 'able'), ('particular', 'amod', 'spirit'), ('nolans', 'nsubj', 'spirit'), ('spirit', 'ccomp', 'find'), ('itthe', 'compound', 'batman'), ('batman', 'nmod', 'time'), ('trilogy', 'npadvmod', 'best'), ('best', 'amod', 'time'), ('superhero', 'compound', 'saga'), ('saga', 'compound', 'time'), ('time', 'compound', 'doubt'), ('peak', 'compound', 'knight'), ('dark', 'compound', 'knight'), ('knight', 'compound', 'doubt'), ('doubt', 'compound', 'masterpiece'), ('masterpiece', 'conj', 'left'), ('well', 'advmod', 'left'), ('nonetheless', 'advmod', 'left'), ('every', 'det', 'time'), ('time', 'npadvmod', 'talk'), ('talk', 'nmod', 'jokerthen'), ('heath', 'compound', 'ledger'), ('ledger', 'nsubj', 'takes'), ('takes', 'ccomp', 'talk'), ('spotlights', 'compound', 'lifetimerole'), ('lifetimerole', 'dobj', 'takes'), ('uniqueandonly', 'amod', 'jokerthen'), ('jokerthen', 'nsubj', 'came'), ('came', 'ROOT', 'came'), ('inception', 'compound', 'nolan'), ('nolan', 'nsubj', 'stood'), ('truly', 'advmod', 'stood'), ('stood', 'advcl', 'came'), ('every', 'det', 'work'), ('single', 'amod', 'work'), ('detail', 'compound', 'work'), ('work', 'nsubj', 'done'), ('done', 'nsubj', 'remains'), ('finest', 'amod', 'way'), ('way', 'nmod', 'storyline'), ('multilayered', 'amod', 'storyline'), ('storyline', 'dobj', 'done'), ('despite', 'prep', ' ...
# [('inception', 'nsubj', 'gordonlevitt'), ('written', 'acl', 'inception'), ('produced', 'amod', 'dicaprio'), ('directed', 'amod', 'stars'), ('christopher', 'compound', 'stars'), ('nolan', 'compound', 'stars'), ('film', 'compound', 'stars'), ('stars', 'compound', 'dicaprio'), ('leonardo', 'compound', 'dicaprio'), ('dicaprio', 'dobj', 'written'), ('ken', 'compound', 'joseph'), ('watanabe', 'compound', 'joseph'), ('joseph', 'nsubj', 'gordonlevitt'), ('gordonlevitt', 'nsubj', 'played'), ('marion', 'dobj', 'gordonlevitt'), ('cotillard', 'amod', 'ellen'), ('ellen', 'compound', 'page'), ('page', 'dobj', 'gordonlevitt'), ('tom', 'npadvmod', 'gordonlevitt'), ('hardy', 'amod', 'rao'), ('cillian', 'amod', 'rao'), ('murphy', 'compound', 'dileep'), ('dileep', 'compound', 'rao'), ('rao', 'compound', 'berenger'), ('tom', 'compound', 'berenger'), ('berenger', 'npadvmod', 'gordonlevitt'), ('michael', 'nsubj', 'caine'), ('caine', 'ccomp', 'gordonlevitt'), ('musical', 'amod', 'score'), ('score', 'compound', 'hans'), ('hans', 'compound', 'plot'), ('zimmer', 'compound', 'plot'), ('wally', 'advmod', 'cinematographer'), ('pfister', 'compound', 'cinematographer'), ('cinematographer', 'compound', 'plot'), ('plot', 'nsubj', 'finds'), ('finds', 'ccomp', 'gordonlevitt'), ('dicaprio', 'nsubj', 'playing'), ('playing', 'ccomp', 'finds'), ('dom', 'compound', 'cobb'), ('cobb', 'compound', 'ideas'), ('specialised', 'compound', 'hire'), ('spy', 'compound', 'hire'), ('hire', 'compound', 'steals'), ('steals', 'compound', 'ideas'), ('ideas', 'dobj', 'playing'), ('dreams', 'dep', 'playing'), ('people', 'nsubj', 'gets'), ('one', 'nummod', 'day'), ('day', 'nsubj', 'gets'), ('gets', 'ccomp', 'finds'), ('different', 'amod', 'offer'), ('offer', 'dobj', 'gets'), ('one', 'nummod', 'enable'), ('enable', 'nsubj', 'see'), ('see', 'acl', 'offer'), ('estranged', 'amod', 'children'), ('children', 'nsubj', 'get'), ('get', 'ccomp', 'see'), ('reward', 'nsubj', 'enact'), ('must', 'aux', 'enact'), ('enact', 'ccomp', 'get'), ('inception', 'compound', 'planting'), ('planting', 'compound', 'mind'), ('idea', 'compound', 'mind'), ('mind', 'compound', 'inception'), ('selected', 'amod', 'inception'), ('target', 'compound', 'inception'), ('inception', 'nsubj', 'thought'), ('thought', 'ccomp', 'finds'), ('impossible', 'amod', 'cobb'), ('cobb', 'nmod', 'team'), ('selected', 'amod', 'team'), ('team', 'nsubj', 'fail'), ('fail', 'ccomp', 'thought'), ('consequences', 'dobj', 'fail'), ('unthinkablethere', 'advmod', 'written'), ('already', 'advmod', 'written'), ('much', 'advmod', 'written'), ('written', 'amod', 'pondered'), ('pondered', 'amod', 'regards'), ('regards', 'compound', 'inception'), ('inception', 'ccomp', 'thought'), ('relatively', 'advmod', 'short'), ('short', 'amod', 'time'), ('running', 'amod', 'time'), ('time', 'nsubj', 'said'), ('life', 'nmod', 'imagine'), ('one', 'nummod', 'life'), ('imagine', 'nsubj', 'said'), ('written', 'acl', 'imagine'), ('said', 'ccomp', 'thought'), ('ten', 'nummod', 'years'), ('years', 'compound', 'time'), ('time', 'npadvmod', 'said'), ('although', 'mark', 'bit'), ('arguably', 'advmod', 'bit'), ('bit', 'npadvmod', 'likes'), ('early', 'advmod', 'bit'), ('talking', 'acl', 'bit'), ('held', 'acl', 'bit'), ('high', 'amod', 'regards'), ('regards', 'dobj', 'bit'), ('likes', 'ccomp', 'said'), ('space', 'compound', 'odyssey'), ('odyssey', 'nmod', 'nolan'), ('inescapable', 'amod', 'movie'), ('nolans', 'compound', 'movie'), ('movie', 'nmod', 'nolan'), ('current', 'amod', 'generations'), ('generations', 'nmod', 'scifi'), ('scifi', 'nmod', 'nolan'), ('classic', 'amod', 'nolan'), ('nolan', 'nsubj', 'managed'), ('managed', 'xcomp', 'likes'), ('make', 'xcomp', 'managed'), ('accessible', 'amod', 'eyes'), ('mainstream', 'nmod', 'eyes'), ('dazzled', 'amod', 'eyes'), ('eyes', 'nsubj', 'process'), ('much', 'amod', 'process'), ('brain', 'compound', 'process'), ('process', 'compound', 'film'), ('close', 'amod', 'genius'), ('piece', 'compound', 'genius'), ('genius', 'compound', 'craf ...
# [('reading', 'csubj', 'knew'), ('nothing', 'dobj', 'reading'), ('good', 'amod', 'reviews'), ('reviews', 'compound', 'inception'), ('inception', 'dobj', 'reading'), ('past', 'amod', 'weeks'), ('weeks', 'npadvmod', 'reading'), ('knew', 'ccomp', 'say'), ('minute', 'npadvmod', 'saw'), ('saw', 'compound', 'trailer'), ('trailer', 'nsubj', 'see'), ('see', 'compound', 'movie'), ('movie', 'nsubj', 'expect'), ('did', 'aux', 'expect'), ('nt', 'neg', 'know'), ('know', 'advmod', 'expect'), ('expect', 'ccomp', 'knew'), ('seen', 'amod', 'movie'), ('trailer', 'compound', 'movie'), ('movie', 'nsubj', 'know'), ('know', 'parataxis', 'explain'), ('does', 'aux', 'explain'), ('nt', 'neg', 'explain'), ('explain', 'ccomp', 'expect'), ('much', 'advmod', 'saw'), ('saw', 'amod', 'inception'), ('inception', 'dobj', 'explain'), ('today', 'npadvmod', 'explain'), ('say', 'ROOT', 'say'), ('wow', 'intj', 'say'), ('incredible', 'amod', 'director'), ('cast', 'npadvmod', 'amazing'), ('amazing', 'amod', 'director'), ('director', 'nsubj', 'go'), ('ca', 'aux', 'go'), ('nt', 'neg', 'go'), ('go', 'ccomp', 'say'), ('wrong', 'amod', 'movie'), ('inception', 'compound', 'movie'), ('movie', 'nsubj', 'makes'), ('makes', 'advcl', 'go'), ('think', 'nsubj', 'saw'), ('start', 'xcomp', 'think'), ('whole', 'amod', 'conversation'), ('conversation', 'dobj', 'start'), ('saw', 'ccomp', 'makes'), ('screen', 'compound', 'story'), ('clever', 'amod', 'story'), ('story', 'nsubj', 'told'), ('told', 'conj', 'go'), ('skill', 'compound', 'passion'), ('passion', 'nsubj', 'pay'), ('pay', 'ccomp', 'told'), ('attention', 'dobj', 'pay'), ('loved', 'advcl', 'told'), ('made', 'xcomp', 'told'), ('think', 'nsubj', 'love'), ('one', 'nummod', 'friends'), ('friends', 'nsubj', 'saw'), ('saw', 'ccomp', 'think'), ('premiere', 'nsubj', 'told'), ('told', 'ccomp', 'saw'), ('would', 'aux', 'see'), ('see', 'ccomp', 'told'), ('understand', 'dobj', 'see'), ('did', 'aux', 'saw'), ('nt', 'neg', 'saw'), ('get', 'auxpass', 'saw'), ('saw', 'ccomp', 'see'), ('today', 'npadvmod', 'saw'), ('would', 'aux', 'love'), ('love', 'ccomp', 'made'), ('see', 'xcomp', 'love'), ('movie', 'compound', 'problem'), ('problem', 'compound', 'performances'), ('performances', 'compound', 'story'), ('story', 'nsubj', 'sounds'), ('sounds', 'nsubj', 'love'), ('editing', 'csubj', 'love'), ('incredible', 'amod', 'effects'), ('effects', 'dobj', 'editing'), ('would', 'aux', 'love'), ('love', 'ccomp', 'say'), ('watch', 'compound', 'fardom'), ('movie', 'nmod', 'year'), ('favorite', 'amod', 'year'), ('film', 'compound', 'year'), ('year', 'compound', 'fardom'), ('fardom', 'nsubj', 'cobb'), ('cobb', 'xcomp', 'love'), ('skilled', 'amod', 'thief'), ('thief', 'nsubj', 'absolute'), ('absolute', 'amod', 'extraction'), ('best', 'amod', 'extraction'), ('dangerous', 'amod', 'extraction'), ('art', 'compound', 'extraction'), ('extraction', 'dobj', 'love'), ('stealing', 'acl', 'extraction'), ('valuable', 'amod', 'secrets'), ('secrets', 'dobj', 'stealing'), ('deep', 'advmod', 'within'), ('within', 'prep', 'secrets'), ('subconscious', 'amod', 'dream'), ('dream', 'nmod', 'mind'), ('state', 'compound', 'mind'), ('mind', 'pobj', 'within'), ('vulnerable', 'amod', 'cobbs'), ('cobbs', 'compound', 'ability'), ('rare', 'amod', 'ability'), ('ability', 'dobj', 'love'), ('made', 'acl', 'ability'), ('coveted', 'amod', 'player'), ('player', 'nmod', 'espionage'), ('treacherous', 'amod', 'espionage'), ('new', 'amod', 'espionage'), ('world', 'nmod', 'espionage'), ('corporate', 'amod', 'espionage'), ('espionage', 'nsubj', 'made'), ('also', 'advmod', 'made'), ('made', 'ccomp', 'say'), ('international', 'amod', 'fugitive'), ('fugitive', 'nsubj', 'cost'), ('cost', 'ccomp', 'made'), ('everything', 'dobj', 'cost'), ('ever', 'advmod', 'loved'), ('loved', 'amod', 'cobb'), ('cobb', 'nsubj', 'offered'), ('offered', 'ccomp', 'made'), ('chance', 'compound', 'redemption'), ('redemption', 'dobj', 'offered'), ('one', 'nummod', 'job'), ('last', 'amod', 'job'), ('job', 'nsubj', 'give'), ('could',  ...
# [('central', 'amod', 'idea'), ('idea', 'compound', 'inception'), ('inception', 'nmod', 'technology'), ('interesting', 'amod', 'technology'), ('one', 'nummod', 'technology'), ('technology', 'nsubj', 'exists'), ('exists', 'ccomp', 'replaces'), ('enter', 'xcomp', 'exists'), ('peoples', 'dobj', 'enter'), ('dreams', 'cc', 'exists'), ('order', 'nsubj', 'steal'), ('steal', 'conj', 'exists'), ('private', 'amod', 'secrets'), ('secrets', 'dative', 'steal'), ('implant', 'amod', 'ideas'), ('new', 'amod', 'ideas'), ('ideas', 'dobj', 'steal'), ('christopher', 'compound', 'director'), ('nolan', 'nmod', 'director'), ('memento', 'compound', 'writer'), ('fame', 'compound', 'writer'), ('writer', 'compound', 'director'), ('director', 'appos', 'ideas'), ('smart', 'amod', 'movie'), ('compelling', 'amod', 'movie'), ('movie', 'nsubj', 'inception'), ('unfortunately', 'advmod', 'inception'), ('inception', 'conj', 'exists'), ('bloated', 'prep', 'inception'), ('failurethe', 'det', 'problem'), ('root', 'compound', 'problem'), ('problem', 'dobj', 'bloated'), ('nolan', 'nsubj', 'replaces'), ('replaces', 'ROOT', 'replaces'), ('fascinating', 'amod', 'dream'), ('surrealism', 'compound', 'dream'), ('dream', 'nsubj', 'worlds'), ('worlds', 'nsubj', 'outtakes'), ('lengthy', 'amod', 'outtakes'), ('outtakes', 'ccomp', 'replaces'), ('james', 'compound', 'bond'), ('bond', 'compound', 'movies'), ('movies', 'nsubj', 'example'), ('example', 'ccomp', 'outtakes'), ('early', 'amod', 'ariadne'), ('film', 'compound', 'ariadne'), ('cobb', 'compound', 'ariadne'), ('ariadne', 'nsubj', 'sitting'), ('sitting', 'ccomp', 'example'), ('café', 'compound', 'dream'), ('dream', 'compound', 'cobb'), ('world', 'compound', 'cobb'), ('cobb', 'nsubj', 'tells'), ('tells', 'conj', 'replaces'), ('ariadne', 'dobj', 'tells'), ('stay', 'xcomp', 'tells'), ('calm', 'acomp', 'stay'), ('what', 'nsubj', 'going'), ('s', 'aux', 'going'), ('going', 'ccomp', 'stay'), ('happen', 'amod', 'waiter'), ('waiter', 'nsubj', 'bring'), ('going', 'aux', 'bring'), ('bring', 'ccomp', 'going'), ('glass', 'dobj', 'bring'), ('full', 'amod', 'eyeballs'), ('wriggling', 'compound', 'eyeballs'), ('eyeballs', 'dobj', 'bring'), ('going', 'acl', 'eyeballs'), ('turn', 'advmod', 'going'), ('around', 'advmod', 'turn'), ('see', 'dep', 'replaces'), ('best', 'amod', 'friend'), ('friend', 'dobj', 'see'), ('high', 'amod', 'school'), ('school', 'appos', 'friend'), ('sex', 'compound', 'abraham'), ('abraham', 'appos', 'friend'), ('lincoln', 'compound', 'things'), ('things', 'nsubj', 'start'), ('start', 'advcl', 'replaces'), ('exploding', 'xcomp', 'start'), ('that', 'nsubj', 's'), ('s', 'ccomp', 'exploding'), ('whole', 'amod', 'movie'), ('movie', 'nmod', 'nutshell'), ('nutshell', 'nmod', 'effects'), ('gaudy', 'amod', 'effects'), ('special', 'amod', 'effects'), ('effects', 'nsubj', 'scenes'), ('endless', 'amod', 'fight'), ('fight', 'compound', 'scenes'), ('scenes', 'conj', 'replaces'), ('poor', 'nsubj', 'substitute'), ('substitute', 'nsubj', 'is'), ('imaginative', 'amod', 'dreams'), ('ideasthe', 'compound', 'dreams'), ('matryoshkadoll', 'compound', 'plot'), ('plot', 'compound', 'dreams'), ('dreams', 'dobj', 'substitute'), ('within', 'prep', 'substitute'), ('dreams', 'pobj', 'within'), ('is', 'ccomp', 'replaces'), ('nt', 'neg', 'is'), ('nearly', 'advmod', 'hard'), ('hard', 'amod', 'follow'), ('follow', 'attr', 'is'), ('one', 'nsubj', 'imagine'), ('might', 'aux', 'imagine'), ('imagine', 'ccomp', 'replaces'), ('largely', 'advmod', 'imagine'), ('nothing', 'compound', 'consequence'), ('consequence', 'nsubj', 'happens'), ('happens', 'ccomp', 'imagine'), ('higher', 'amod', 'levels'), ('levels', 'compound', 'heroes'), ('heroes', 'nsubj', 'moved'), ('moved', 'ccomp', 'replaces'), ('deeper', 'amod', 'levels'), ('levels', 'compound', 'higherlevel'), ('higherlevel', 'npadvmod', 'supporting'), ('supporting', 'amod', 'actors'), ('actors', 'nsubj', 'fight'), ('fight', 'ccomp', 'moved'), ('bad', 'amod', 'guys'), ('guys', 'dobj', 'fight'), ('overblown', 'advc ...
# [('dom', 'compound', 'cobb'), ('cobb', 'nsubj', 'leads'), ('leads', 'ROOT', 'leads'), ('highly', 'advmod', 'skilled'), ('skilled', 'amod', 'team'), ('team', 'dobj', 'leads'), ('specializing', 'acl', 'team'), ('stealing', 'xcomp', 'specializing'), ('secrets', 'compound', 'peoples'), ('peoples', 'dobj', 'stealing'), ('minds', 'prep', 'leads'), ('entering', 'advcl', 'leads'), ('dreams', 'nsubj', 'shot'), ('hired', 'acl', 'dreams'), ('mysterious', 'amod', 'businessman'), ('businessman', 'compound', 'cobb'), ('cobb', 'dobj', 'hired'), ('finally', 'advmod', 'shot'), ('shot', 'conj', 'leads'), ('redemption', 'compound', 'achieving'), ('achieving', 'dobj', 'shot'), ('near', 'prep', 'achieving'), ('impossible', 'amod', 'near'), ('rather', 'advmod', 'stealing'), ('stealing', 'amod', 'idea'), ('idea', 'pobj', 'near'), ('must', 'aux', 'complete'), ('complete', 'ccomp', 'shot'), ('opposite', 'amod', 'ideainception'), ('inception', 'compound', 'planting'), ('planting', 'compound', 'seed'), ('seed', 'compound', 'ideainception'), ('ideainception', 'dobj', 'complete'), ('multilayered', 'amod', 'plot'), ('plot', 'dobj', 'complete'), ('quite', 'advmod', 'literally'), ('literally', 'advmod', 'fact'), ('fact', 'nsubj', 'focuses'), ('focuses', 'conj', 'leads'), ('emotional', 'amod', 'journey'), ('journey', 'compound', 'character'), ('lead', 'compound', 'character'), ('character', 'compound', 'time'), ('cobb', 'compound', 'time'), ('time', 'compound', 'thrusts'), ('thrusts', 'nsubj', 'audience'), ('audience', 'compound', 'story'), ('multiple', 'compound', 'levels'), ('levels', 'nmod', 'story'), ('action', 'npadvmod', 'packed'), ('packed', 'amod', 'story'), ('story', 'nsubj', 'telling'), ('telling', 'ccomp', 'focuses'), ('distinct', 'amod', 'one'), ('one', 'nmod', 'intellect'), ('another', 'det', 'film'), ('finely', 'advmod', 'connected'), ('connected', 'amod', 'film'), ('described', 'amod', 'critics'), ('critics', 'compound', 'film'), ('film', 'nmod', 'intellect'), ('rewards', 'compound', 'intellect'), ('intellect', 'dobj', 'telling'), ('assure', 'ccomp', 'telling'), ('exactly', 'advmod', 'nolan'), ('director', 'compound', 'nolan'), ('christopher', 'compound', 'nolan'), ('nolan', 'nsubj', 'challenges'), ('challenges', 'ccomp', 'assure'), ('audience', 'nsubj', 'keep'), ('keep', 'ccomp', 'challenges'), ('rewards', 'dobj', 'keep'), ('breathtaking', 'acl', 'rewards'), ('spectacle', 'nmod', 'part'), ('one', 'nummod', 'capability'), ('capability', 'nsubj', 'leave'), ('leave', 'relcl', 'spectacle'), ('awestruck', 'dobj', 'leave'), ('best', 'amod', 'part'), ('part', 'nsubj', 'feel'), ('may', 'aux', 'feel'), ('feel', 'ccomp', 'assure'), ('need', 'aux', 'watch'), ('watch', 'xcomp', 'feel'), ('able', 'acomp', 'watch'), ('fully', 'advmod', 'absorb'), ('absorb', 'advcl', 'feel'), ('experience', 'compound', 'chances'), ('chances', 'dobj', 'absorb'), ('probably', 'advmod', 'want'), ('want', 'ccomp', 'telling'), ('tochristopher', 'nummod', 'nolan'), ('nolan', 'nsubj', 'brings'), ('brings', 'ccomp', 'want'), ('unique', 'amod', 'screen'), ('vision', 'compound', 'screen'), ('screen', 'compound', 'help'), ('help', 'dobj', 'brings'), ('starstudded', 'advcl', 'leads'), ('cast', 'dobj', 'starstudded'), ('including', 'prep', 'cast'), ('likes', 'compound', 'dicaprio'), ('leonardo', 'compound', 'dicaprio'), ('dicaprio', 'pobj', 'including'), ('departed', 'conj', 'leads'), ('joseph', 'compound', 'gordonlevitt'), ('gordonlevitt', 'compound', 'days'), ('days', 'compound', 'enemies'), ('summer', 'compound', 'ellen'), ('ellen', 'compound', 'page'), ('page', 'nmod', 'marion'), ('juno', 'compound', 'marion'), ('marion', 'nmod', 'enemies'), ('cotillard', 'amod', 'enemies'), ('public', 'amod', 'enemies'), ('enemies', 'nsubj', 'cillian'), ('cillian', 'compound', 'batman'), ('murphy', 'compound', 'batman'), ('batman', 'nsubj', 'begins'), ('begins', 'ccomp', 'departed'), ('michael', 'compound', 'caine'), ('caine', 'compound', 'knight'), ('dark', 'compound', 'knight'), ('knight', 'nmod', ...
# [('film', 'compound', 'disappointment'), ('disappointment', 'nsubj', 'gordonlevitt'), ('little', 'advmod', 'much'), ('much', 'advmod', 'interesting'), ('basically', 'advmod', 'interesting'), ('interesting', 'amod', 'gordonlevitt'), ('scifi', 'compound', 'heist'), ('heist', 'compound', 'cobb'), ('premise', 'compound', 'cobb'), ('cobb', 'compound', 'dicaprio'), ('leonardo', 'compound', 'dicaprio'), ('dicaprio', 'compound', 'joseph'), ('arthur', 'compound', 'joseph'), ('joseph', 'nsubj', 'gordonlevitt'), ('gordonlevitt', 'nsubj', 'steal'), ('partners', 'nsubj', 'use'), ('use', 'ccomp', 'gordonlevitt'), ('dreaminvasion', 'compound', 'technology'), ('technology', 'dobj', 'use'), ('steal', 'ccomp', 'travel'), ('industrial', 'amod', 'secrets'), ('secrets', 'dobj', 'steal'), ('unsuspecting', 'acl', 'secrets'), ('mass', 'compound', 'transit'), ('transit', 'compound', 'passengers'), ('passengers', 'dobj', 'unsuspecting'), ('powerful', 'amod', 'people'), ('people', 'nmod', 'age'), ('technological', 'amod', 'age'), ('age', 'nsubj', 'travel'), ('would', 'aux', 'travel'), ('travel', 'ROOT', 'travel'), ('mass', 'compound', 'transit'), ('transit', 'dobj', 'travel'), ('one', 'nummod', 'film'), ('many', 'amod', 'film'), ('obvious', 'amod', 'film'), ('questions', 'compound', 'film'), ('film', 'nsubj', 'expects'), ('expects', 'conj', 'travel'), ('us', 'nsubj', 'raise'), ('raise', 'ccomp', 'expects'), ('doze', 'amod', 'cobb'), ('exchange', 'compound', 'immunity'), ('immunity', 'nmod', 'cobb'), ('troubling', 'amod', 'cobb'), ('criminal', 'amod', 'charge'), ('charge', 'compound', 'cobb'), ('cobb', 'dobj', 'raise'), ('agree', 'ccomp', 'expects'), ('undertake', 'xcomp', 'agree'), ('unprecedented', 'amod', 'practice'), ('mission', 'compound', 'practice'), ('practice', 'compound', 'inception'), ('inception', 'nmod', 'plant'), ('powerful', 'amod', 'plant'), ('business', 'compound', 'scion'), ('scion', 'compound', 'plant'), ('plant', 'nmod', 'manipulationall'), ('original', 'amod', 'idea'), ('idea', 'nmod', 'dream'), ('subconscious', 'amod', 'dream'), ('dream', 'compound', 'manipulationall'), ('manipulationall', 'dobj', 'undertake'), ('great', 'amod', 'manipulationall'), ('unfortunately', 'advmod', 'find'), ('none', 'nmod', 'weight'), ('emotional', 'amod', 'weight'), ('weight', 'nsubj', 'find'), ('find', 'nsubj', 'seems'), ('look', 'xcomp', 'find'), ('mystery', 'compound', 'cobb'), ('cobb', 'compound', 'wife'), ('exile', 'compound', 'wife'), ('plot', 'compound', 'wife'), ('wife', 'compound', 'cotillard'), ('marion', 'compound', 'cotillard'), ('cotillard', 'nsubj', 'shared'), ('shared', 'amod', 'movie'), ('disastrous', 'amod', 'dream'), ('traumatic', 'amod', 'dream'), ('experience', 'compound', 'dream'), ('dream', 'compound', 'movie'), ('sharing', 'compound', 'movie'), ('movie', 'nsubj', 'falls'), ('essentially', 'advmod', 'falls'), ('falls', 'ccomp', 'find'), ('apart', 'advmod', 'falls'), ('seems', 'ccomp', 'expects'), ('like', 'mark', 'synthesized'), ('nolan', 'compound', 'writers'), ('writers', 'nsubj', 'synthesized'), ('never', 'neg', 'synthesized'), ('fully', 'advmod', 'synthesized'), ('synthesized', 'advcl', 'seems'), ('two', 'nummod', 'strains'), ('dominant', 'amod', 'strains'), ('strains', 'compound', 'time'), ('film', 'compound', 'time'), ('time', 'nmod', 'drama'), ('emotional', 'amod', 'drama'), ('drama', 'nmod', 'point'), ('getting', 'acl', 'drama'), ('way', 'dobj', 'getting'), ('heist', 'amod', 'film'), ('film', 'compound', 'point'), ('vice', 'compound', 'versa'), ('versa', 'amod', 'point'), ('point', 'nsubj', 'seem'), ('seem', 'advcl', 'synthesized'), ('heist', 'advmod', 'complimenting'), ('complimenting', 'xcomp', 'seem'), ('drama', 'dobj', 'complimenting'), ('vice', 'advmod', 'versa'), ('versa', 'amod', 'fact'), ('fact', 'acl', 'drama'), ('impressive', 'amod', 'effects'), ('effects', 'compound', 'sequences'), ('sequences', 'compound', 'scenes'), ('scenes', 'compound', 'cobb'), ('cobb', 'nsubj', 'shows'), ('shows', 'ccomp', 'complimenting'),  ...
# [('surrealism', 'nsubj', 'appear'), ('appear', 'ROOT', 'appear'), ('ineffably', 'advmod', 'bizarre'), ('bizarre', 'oprd', 'appear'), ('inquisitively', 'advmod', 'titillating'), ('titillating', 'advmod', 'bizarre'), ('depending', 'prep', 'titillating'), ('purely', 'advmod', 'viewers'), ('viewers', 'pobj', 'depending'), ('intellect', 'oprd', 'appear'), ('though', 'mark', 'complex'), ('realm', 'compound', 'surrealism'), ('surrealism', 'nsubj', 'complex'), ('highly', 'advmod', 'nebulous'), ('nebulous', 'amod', 'complex'), ('complex', 'amod', 'improvisation'), ('even', 'advmod', 'attempt'), ('slight', 'amod', 'attempt'), ('attempt', 'compound', 'improvisation'), ('improvisation', 'nsubj', 'go'), ('sometimes', 'advmod', 'go'), ('go', 'conj', 'appear'), ('awry', 'advmod', 'open'), ('open', 'amod', 'box'), ('pandoras', 'compound', 'box'), ('box', 'nsubj', 'making'), ('making', 'advcl', 'go'), ('task', 'dobj', 'making'), ('highly', 'advmod', 'improbable'), ('improbable', 'amod', 'reality'), ('nigh', 'amod', 'reality'), ('impossible', 'amod', 'reality'), ('facet', 'compound', 'reality'), ('reality', 'nsubj', 'pose'), ('may', 'aux', 'pose'), ('pose', 'ccomp', 'making'), ('handicap', 'amod', 'genius'), ('gifted', 'amod', 'directors'), ('directors', 'compound', 'genius'), ('genius', 'compound', 'dabbles'), ('christopher', 'compound', 'dabbles'), ('nolan', 'compound', 'dabbles'), ('dabbles', 'nsubj', 'concept'), ('concept', 'compound', 'surrealism'), ('surrealism', 'nsubj', 'blends'), ('also', 'advmod', 'blends'), ('ingeniously', 'advmod', 'blends'), ('blends', 'ccomp', 'pose'), ('elements', 'compound', 'fiction'), ('science', 'compound', 'fiction'), ('fiction', 'dobj', 'blends'), ('latest', 'amod', 'wonder'), ('wonder', 'dobj', 'blends'), ('named', 'acl', 'wonder'), ('inception', 'compound', 'nolan'), ('nolan', 'oprd', 'named'), ('created', 'amod', 'decade'), ('niche', 'compound', 'decade'), ('decade', 'npadvmod', 'back'), ('back', 'advmod', 'unleashing'), ('unleashing', 'xcomp', 'named'), ('monster', 'compound', 'movie'), ('movie', 'dobj', 'unleashing'), ('called', 'acl', 'movie'), ('memento', 'nmod', 'status'), ('substantiated', 'amod', 'status'), ('status', 'oprd', 'called'), ('conjuring', 'advcl', 'pose'), ('movies', 'dobj', 'conjuring'), ('like', 'prep', 'movies'), ('insomnia', 'compound', 'batman'), ('prestige', 'compound', 'batman'), ('batman', 'pobj', 'like'), ('begins', 'conj', 'pose'), ('dark', 'amod', 'knight'), ('knight', 'dobj', 'begins'), ('unremitting', 'conj', 'begins'), ('desire', 'compound', 'innovation'), ('innovation', 'dobj', 'unremitting'), ('uncanny', 'advmod', 'foray'), ('craving', 'compound', 'foray'), ('foray', 'compound', 'imagination'), ('unexplored', 'amod', 'realms'), ('realms', 'compound', 'imagination'), ('imagination', 'nsubj', 'gave'), ('deservedly', 'advmod', 'earned'), ('earned', 'acl', 'imagination'), ('auteur', 'compound', 'tag'), ('tag', 'dobj', 'earned'), ('gave', 'conj', 'go'), ('carte', 'compound', 'storyteller'), ('blanche', 'compound', 'storyteller'), ('storyteller', 'dobj', 'gave'), ('like', 'prep', 'storyteller'), ('nolan', 'pobj', 'like'), ('desperately', 'advmod', 'needs'), ('needs', 'conj', 'go'), ('highly', 'advmod', 'apparent'), ('apparent', 'amod', 'nolan'), ('nolan', 'nsubj', 'takes'), ('takes', 'ccomp', 'needs'), ('every', 'det', 'liberty'), ('possible', 'amod', 'liberty'), ('advantage', 'compound', 'liberty'), ('liberty', 'dobj', 'takes'), ('filming', 'amod', 'thing'), ('inception', 'compound', 'inception'), ('inception', 'nmod', 'dream'), ('dreamlike', 'nmod', 'dream'), ('dream', 'nmod', 'thing'), ('superior', 'amod', 'thing'), ('thing', 'nsubj', 'conceived'), ('conceived', 'ccomp', 'takes'), ('silver', 'compound', 'screen'), ('screen', 'nmod', 'part'), ('entwined', 'amod', 'layers'), ('layers', 'compound', 'movie'), ('movie', 'compound', 'part'), ('part', 'nsubj', 'serves'), ('serves', 'advcl', 'conceived'), ('unfathomable', 'amod', 'riddle'), ('riddle', 'nsubj', 'makes'), ('makes',  ...
# [('one', 'nsubj', 'goes'), ('goes', 'ROOT', 'goes'), ('art', 'compound', 'gallery'), ('gallery', 'nsubj', 'see'), ('see', 'ccomp', 'goes'), ('provocative', 'amod', 'piece'), ('piece', 'compound', 'one'), ('one', 'nsubj', 'sees'), ('sees', 'ccomp', 'see'), ('something', 'dobj', 'sees'), ('new', 'amod', 'time'), ('time', 'nsubj', 'tour'), ('that', 'nsubj', 's'), ('s', 'relcl', 'time'), ('true', 'amod', 'art'), ('art', 'attr', 's'), ('that', 'nsubj', 's'), ('s', 'relcl', 'art'), ('black', 'amod', 'light'), ('light', 'compound', 'film'), ('elvis', 'compound', 'film'), ('art', 'compound', 'film'), ('film', 'attr', 's'), ('certainly', 'advmod', 'tour'), ('tour', 'ccomp', 'sees'), ('de', 'nmod', 'force'), ('force', 'nsubj', 'requires'), ('requires', 'conj', 'goes'), ('engagement', 'dobj', 'requires'), ('every', 'det', 'step'), ('step', 'nsubj', 'give'), ('like', 'prep', 'step'), ('works', 'compound', 'art'), ('art', 'pobj', 'like'), ('does', 'aux', 'give'), ('nt', 'neg', 'give'), ('give', 'advcl', 'requires'), ('away', 'prt', 'give'), ('look', 'xcomp', 'give'), ('forward', 'advmod', 'look'), ('seeing', 'advcl', 'give'), ('second', 'advmod', 'seeing'), ('even', 'advmod', 'time'), ('third', 'amod', 'time'), ('time', 'npadvmod', 'seeing'), ('first', 'amod', 'premise'), ('premise', 'nsubj', 'engaging'), ('wonderfully', 'advmod', 'engaging'), ('engaging', 'ccomp', 'seeing'), ('consciousness', 'compound', 'layered'), ('layered', 'dobj', 'engaging'), ('everyone', 'nsubj', 'knows'), ('knows', 'relcl', 'layered'), ('thinks', 'ccomp', 'knows'), ('awakened', 'advcl', 'engaging'), ('find', 'xcomp', 'requires'), ('another', 'det', 'nightmarethen'), ('nightmarethen', 'nsubj', 'know'), ('awaken', 'nsubj', 'know'), ('know', 'ccomp', 'find'), ('subconscious', 'amod', 'nature'), ('nature', 'nsubj', 'control'), ('control', 'nmod', 'layer'), ('wonderful', 'amod', 'layer'), ('premise', 'compound', 'layer'), ('layer', 'nsubj', 'ends'), ('people', 'nsubj', 'flip'), ('flip', 'relcl', 'layer'), ('use', 'dobj', 'flip'), ('ends', 'ccomp', 'know'), ('confusing', 'xcomp', 'ends'), ('exciting', 'amod', 'thing'), ('amazing', 'amod', 'thing'), ('thing', 'dobj', 'confusing'), ('directorwriter', 'nsubj', 'pulls'), ('pulls', 'ccomp', 'ends'), ('every', 'det', 'event'), ('nuance', 'compound', 'event'), ('event', 'npadvmod', 'goes'), ('picked', 'acl', 'event'), ('precisely', 'advmod', 'effectiveness'), ('effectiveness', 'compound', 'luxury'), ('luxury', 'dobj', 'picked'), ('watching', 'acl', 'event'), ('one', 'nummod', 'care'), ('precipice', 'compound', 'abyss'), ('abyss', 'compound', 'care'), ('care', 'compound', 'people'), ('people', 'nsubj', 'want'), ('want', 'ccomp', 'watching'), ('succeed', 'xcomp', 'want'), ('care', 'compound', 'matrix'), ('matrix', 'compound', 'dream'), ('dream', 'compound', 'levels'), ('levels', 'dobj', 'succeed'), ('great', 'amod', 'movie'), ('movie', 'dobj', 'want')]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# [('ask', 'ROOT', 'ask'), ('summer', 'compound', 'blockbuster'), ('blockbuster', 'compound', 'incites'), ('incites', 'compound', 'hysteria'), ('hysteria', 'compound', 'time'), ('time', 'dobj', 'ask'), ('every', 'det', 'year'), ('year', 'npadvmod', 'ask'), ('whatever', 'dobj', 'churn'), ('dross', 'amod', 'studios'), ('studios', 'nsubj', 'churn'), ('churn', 'csubj', 'boils'), ('epic', 'amod', 'hugeness'), ('hugeness', 'dobj', 'churn'), ('blowing', 'advcl', 'churn'), ('stuff', 'compound', 'romance'), ('romance', 'compound', 'heroes'), ('action', 'compound', 'heroes'), ('heroes', 'nsubj', 'boils'), ('looking', 'acl', 'heroes'), ('blockbuster', 'compound', 'think'), ('think', 'dobj', 'looking'), ('boils', 'ccomp', 'ask'), ('thrills', 'dobj', 'boils'), ('audiences', 'nsubj', 'want'), ('want', 'ccomp', 'ask'), ('thrill', 'compound', 'chase'), ('car', 'compound', 'chase'), ('chase', 'compound', 'romance'), ('thrill', 'compound', 'romance'), ('romance', 'compound', 'inception'), ('thrill', 'compound', 'inception'), ('spectacular', 'amod', 'case'), ('case', 'compound', 'inception'), ('inception', 'nsubj', 'greatest'), ('might', 'aux', 'greatest'), ('greatest', 'ccomp', 'want'), ('summer', 'compound', 'blockbuster'), ('blockbuster', 'compound', 'time'), ('time', 'nsubj', 'contains'), ('also', 'advmod', 'contains'), ('contains', 'conj', 'ask'), ('something', 'dobj', 'contains'), ('often', 'advmod', 'look'), ('do', 'aux', 'look'), ('nt', 'neg', 'look'), ('look', 'relcl', 'something'), ('forbrains', 'acl', 'something'), ('resilient', 'amod', 'idea'), ('parasite', 'compound', 'idea'), ('idea', 'nsubj', 'says'), ('says', 'ccomp', 'ask'), ('leonardo', 'compound', 'character'), ('di', 'compound', 'character'), ('caprios', 'compound', 'character'), ('character', 'nsubj', 'cobb'), ('cobb', 'ccomp', 'says'), ('well', 'advmod', 'inception'), ('inception', 'advcl', 'cobb'), ('ideas', 'dobj', 'inception'), ('right', 'amod', 'film'), ('title', 'compound', 'film'), ('film', 'nmod', 'idea'), ('central', 'amod', 'idea'), ('idea', 'nsubj', 'revolves'), ('revolves', 'ccomp', 'says'), ('around', 'prep', 'revolves'), ('extractors', 'pobj', 'around'), ('paid', 'acl', 'extractors'), ('extract', 'compound', 'secrets'), ('secrets', 'compound', 'peoples'), ('peoples', 'nmod', 'minds'), ('subconscious', 'amod', 'minds'), ('minds', 'nsubj', 'purpose'), ('sneaking', 'acl', 'minds'), ('dreams', 'dobj', 'sneaking'), ('usually', 'advmod', 'purpose'), ('purpose', 'advcl', 'revolves'), ('corporate', 'amod', 'espionage'), ('espionage', 'dobj', 'purpose'), ('however', 'advmod', 'asks'), ('one', 'nummod', 'client'), ('client', 'nsubj', 'asks'), ('asks', 'advcl', 'purpose'), ('plant', 'compound', 'idea'), ('idea', 'compound', 'mind'), ('mind', 'compound', 'inception'), ('corporate', 'amod', 'rival'), ('rival', 'amod', 'inception'), ('inception', 'nsubj', 'said'), ('born', 'acl', 'inception'), ('less', 'advmod', 'said'), ('said', 'ccomp', 'asks'), ('film', 'nmod', 'invention'), ('better', 'amod', 'invention'), ('full', 'amod', 'ideas'), ('ideas', 'compound', 'invention'), ('invention', 'nsubj', 'set'), ('set', 'compound', 'genius'), ('piece', 'compound', 'genius'), ('divulge', 'compound', 'piece'), ('piece', 'compound', 'genius'), ('films', 'compound', 'genius'), ('genius', 'nsubj', 'weakened'), ('weakened', 'amod', 'film'), ('film', 'nsubj', 'brings'), ('cleverly', 'advmod', 'brings'), ('intricately', 'advmod', 'brings'), ('brings', 'ccomp', 'said'), ('audience', 'dobj', 'brings'), ('several', 'amod', 'planes'), ('planes', 'compound', 'existence'), ('existence', 'dobj', 'brings'), ('simultaneously', 'advmod', 'allows'), ('never', 'neg', 'allows'), ('allows', 'advcl', 'revolves'), ('viewer', 'nsubj', 'feel'), ('feel', 'ccomp', 'allows'), ('lost', 'amod', 'imagine'), ('power', 'compound', 'imagine'), ('christopher', 'compound', 'imagine'), ('nolans', 'compound', 'imagine'), ('script', 'compound', 'imagine'), ('imagine', 'nsubjpass', 'overlooked'), ('likely', 'advmod', 'overlook ...
# [('inception', 'nsubj', 'concept'), ('truly', 'advmod', 'one'), ('one', 'nummod', 'concept'), ('kind', 'compound', 'concept'), ('concept', 'compound', 'try'), ('long', 'advmod', 'gestated'), ('gestated', 'amod', 'drama'), ('christopher', 'compound', 'nolans'), ('nolans', 'compound', 'mind'), ('mind', 'compound', 'eye'), ('eye', 'compound', 'drama'), ('drama', 'nsubj', 'mixed'), ('mixed', 'relcl', 'concept'), ('large', 'amod', 'scale'), ('scale', 'compound', 'sensibilities'), ('sensibilities', 'dobj', 'mixed'), ('ring', 'advcl', 'mixed'), ('true', 'amod', 'season'), ('blockbuster', 'compound', 'season'), ('season', 'dobj', 'ring'), ('making', 'advcl', 'ring'), ('inception', 'dobj', 'making'), ('true', 'amod', 'remakes'), ('original', 'amod', 'reboots'), ('sea', 'compound', 'reboots'), ('reboots', 'compound', 'remakes'), ('remakes', 'dobj', 'inception'), ('sequelsto', 'compound', 'try'), ('try', 'nsubj', 'open'), ('explain', 'xcomp', 'try'), ('inceptions', 'dobj', 'explain'), ('many', 'amod', 'twists'), ('plot', 'compound', 'twists'), ('twists', 'nsubj', 'foolish'), ('incredibly', 'advmod', 'intelligent'), ('intelligent', 'amod', 'arcs'), ('arcs', 'appos', 'twists'), ('would', 'aux', 'foolish'), ('foolish', 'ccomp', 'explain'), ('task', 'compound', 'nolan'), ('nolan', 'dobj', 'foolish'), ('reluctant', 'amod', 'way'), ('best', 'amod', 'way'), ('way', 'compound', 'film'), ('approach', 'compound', 'film'), ('film', 'nsubj', 'open'), ('would', 'aux', 'open'), ('open', 'csubj', 'delivers'), ('mind', 'dobj', 'open'), ('prepared', 'advcl', 'open'), ('taken', 'conj', 'open'), ('ride', 'compound', 'lifetime'), ('lifetime', 'compound', 'technology'), ('trust', 'compound', 'technology'), ('avatar', 'compound', 'technology'), ('seminal', 'amod', 'film'), ('film', 'compound', 'technology'), ('technology', 'dobj', 'taken'), ('although', 'mark', 'coming'), ('coming', 'advcl', 'open'), ('rather', 'advmod', 'poor'), ('poor', 'amod', 'inception'), ('film', 'compound', 'opinion'), ('opinion', 'compound', 'inception'), ('inception', 'nmod', 'minute'), ('seminal', 'amod', 'minute'), ('storytelling', 'amod', 'minute'), ('minute', 'dobj', 'coming'), ('running', 'compound', 'time'), ('time', 'npadvmod', 'coming'), ('would', 'aux', 'expect'), ('expect', 'conj', 'open'), ('lot', 'nsubj', 'take'), ('take', 'ccomp', 'expect'), ('place', 'dobj', 'take'), ('would', 'aux', 'expect'), ('nt', 'neg', 'expect'), ('expect', 'conj', 'open'), ('pace', 'nsubj', 'think'), ('think', 'ccomp', 'expect'), ('one', 'nummod', 'time'), ('time', 'npadvmod', 'blown'), ('film', 'nsubj', 'blown'), ('long', 'advmod', 'left'), ('left', 'acl', 'film'), ('simply', 'advmod', 'blown'), ('blown', 'ccomp', 'think'), ('away', 'advmod', 'blown'), ('depth', 'dobj', 'blown'), ('every', 'det', 'film'), ('single', 'amod', 'film'), ('part', 'compound', 'film'), ('film', 'compound', 'enthusiasm'), ('enthusiasm', 'npadvmod', 'storytelling'), ('storytelling', 'amod', 'film'), ('aspect', 'compound', 'film'), ('film', 'nsubj', 'worry'), ('left', 'acl', 'film'), ('worried', 'amod', 'spectacle'), ('spectacle', 'dobj', 'left'), ('do', 'aux', 'worry'), ('nt', 'neg', 'worry'), ('worry', 'conj', 'open'), ('hinted', 'amod', 'trailer'), ('trailer', 'nmod', 'action'), ('incredible', 'amod', 'looking'), ('looking', 'amod', 'action'), ('real', 'advmod', 'unbelievable'), ('unbelievable', 'amod', 'action'), ('simultaneously', 'advmod', 'pleasing'), ('pleasing', 'amod', 'action'), ('thing', 'compound', 'action'), ('action', 'nsubj', 'set'), ('set', 'ccomp', 'worry'), ('pieces', 'nsubj', 'used'), ('genuinely', 'advmod', 'used'), ('used', 'advcl', 'open'), ('illustrate', 'amod', 'story'), ('story', 'dobj', 'used'), ('rather', 'advmod', 'blow'), ('blow', 'advcl', 'open'), ('stuff', 'dobj', 'blow'), ('la', 'compound', 'michael'), ('michael', 'dep', 'open'), ('baywith', 'prep', 'open'), ('complex', 'amod', 'movie'), ('movie', 'nmod', 'concept'), ('high', 'amod', 'concept'), ('concept', 'nmod', 'nolan'), ('stellar', 'a ...
# [('saw', 'advcl', 'say'), ('memento', 'dobj', 'saw'), ('recently', 'advmod', 'turned'), ('something', 'nsubj', 'turned'), ('turned', 'ccomp', 'saw'), ('great', 'amod', 'missi'), ('missi', 'dobj', 'turned'), ('saw', 'dep', 'turned'), ('make', 'ccomp', 'saw'), ('couple', 'nsubj', 'thins'), ('thins', 'nsubj', 'straightand'), ('straightand', 'ccomp', 'make'), ('ill', 'advmod', 'make'), ('definitely', 'advmod', 'inceptionchristopher'), ('inceptionchristopher', 'ccomp', 'make'), ('nolan', 'dobj', 'inceptionchristopher'), ('keeps', 'conj', 'saw'), ('improving', 'xcomp', 'keeps'), ('even', 'advmod', 'script'), ('complex', 'amod', 'script'), ('multilayer', 'compound', 'script'), ('script', 'dobj', 'improving'), ('like', 'prep', 'script'), ('thisand', 'pobj', 'like'), ('thought', 'ccomp', 'saw'), ('memento', 'nsubj', 'reach'), ('hard', 'advmod', 'reach'), ('reach', 'ccomp', 'thought'), ('viewers', 'compound', 'noinception'), ('noinception', 'nsubj', 'keep'), ('keep', 'nsubj', 'cast'), ('mesmerized', 'amod', 'genius'), ('captivated', 'amod', 'genius'), ('genius', 'dobj', 'keep'), ('that', 'nsubjpass', 'hidden'), ('s', 'auxpass', 'hidden'), ('hidden', 'relcl', 'genius'), ('behind', 'prep', 'hidden'), ('itand', 'compound', 'directors'), ('directors', 'pobj', 'behind'), ('screenwriters', 'pobj', 'behind'), ('wordsnolan', 'xcomp', 'keep'), ('acting', 'amod', 'effects'), ('soundand', 'compound', 'effects'), ('effects', 'dobj', 'wordsnolan'), ('editing', 'acl', 'effects'), ('wellwhen', 'dobj', 'editing'), ('cast', 'nsubj', 'keeps'), ('like', 'prep', 'cast'), ('thisi', 'compound', 'mean'), ('mean', 'amod', 'gordonlewitt'), ('leonardo', 'compound', 'joseph'), ('dicaprio', 'compound', 'joseph'), ('joseph', 'compound', 'gordonlewitt'), ('gordonlewitt', 'compound', 'caine'), ('michael', 'compound', 'caine'), ('caine', 'compound', 'marion'), ('marion', 'nmod', 'movie'), ('cotillard', 'amod', 'movie'), ('personal', 'amod', 'movie'), ('favourite', 'amod', 'movie'), ('movie', 'pobj', 'like'), ('keeps', 'conj', 'saw'), ('going', 'xcomp', 'keeps'), ('flawlesslymost', 'amod', 'crew'), ('crew', 'compound', 'brothers'), ('nolan', 'compound', 'brothers'), ('brothers', 'nsubj', 'worked'), ('worked', 'ccomp', 'saw'), ('tdk', 'dobj', 'worked'), ('earlier', 'amod', 'categories'), ('batman', 'compound', 'beginsso'), ('beginsso', 'compound', 'noms'), ('oscar', 'compound', 'noms'), ('noms', 'compound', 'categories'), ('categories', 'nsubj', 'certainty'), ('certainty', 'conj', 'worked'), ('methe', 'compound', 'thing'), ('thing', 'dobj', 'certainty'), ('one', 'nsubj', 'movie'), ('could', 'aux', 'movie'), ('movie', 'advcl', 'worked'), ('headache', 'dobj', 'movie'), ('one', 'nsubj', 'havesee'), ('could', 'aux', 'havesee'), ('havesee', 'relcl', 'headache'), ('friends', 'nsubj', 'go'), ('go', 'ccomp', 'havesee'), ('movies', 'nmod', 'action'), ('brainless', 'compound', 'action'), ('action', 'nsubj', 'enjoyed'), ('enjoyed', 'conj', 'saw'), ('iron', 'compound', 'man'), ('man', 'dobj', 'enjoyed'), ('ateam', 'dobj', 'enjoyed'), ('movieyou', 'nsubj', 'see'), ('see', 'aux', 'saw'), ('least', 'advmod', 'twice'), ('twice', 'advmod', 'understand'), ('understand', 'ccomp', 'see'), ('itthe', 'det', 'levels'), ('levels', 'nsubj', 'layers'), ('layers', 'ccomp', 'understand'), ('thing', 'dobj', 'layers'), ('happening', 'acl', 'thing'), ('many', 'amod', 'surelyll'), ('one', 'nummod', 'surelyll'), ('surelyll', 'dobj', 'happening'), ('miss', 'ccomp', 'understand'), ('something', 'dobj', 'miss'), ('vitalthis', 'amod', 'reason'), ('reason', 'nsubj', 'happen'), ('fitting', 'amod', 'hope'), ('mass', 'compound', 'audience'), ('audience', 'compound', 'hope'), ('hope', 'nsubj', 'happen'), ('wo', 'aux', 'happen'), ('nt', 'neg', 'happen'), ('happen', 'ccomp', 'see'), ('nolan', 'dobj', 'happen'), ('one', 'nummod', 'directorswriters'), ('favourite', 'amod', 'directorswriters'), ('directorswriters', 'nsubj', 'showed'), ('showed', 'conj', 'saw'), ('brainless', 'amod', 'flicks'), ('action', 'compound', ...
# ...
# [('first', 'advmod', 'watch'), ('watch', 'advcl', 'gon'), ('movie', 'dobj', 'watch'), ('shocked', 'acl', 'movie'), ('twist', 'npadvmod', 'shocked'), ('i', 'nsubj', 'gon'), ('m', 'aux', 'gon'), ('gon', 'ROOT', 'gon'), ('na', 'aux', 'mention'), ('mention', 'xcomp', 'gon'), ('details', 'nsubj', 'share'), ('ca', 'aux', 'share'), ('nt', 'neg', 'share'), ('share', 'ccomp', 'mention'), ('spoilerssimply', 'compound', 'movie'), ('movie', 'dobj', 'share'), ('makes', 'conj', 'gon'), ('complex', 'amod', 'story'), ('story', 'nsubj', 'makes'), ('makes', 'ccomp', 'makes'), ('question', 'ccomp', 'makes'), ('many', 'amod', 'things'), ('things', 'dobj', 'question'), ('keeping', 'acl', 'things'), ('dreams', 'dobj', 'keeping'), ('whatever', 'det', 'question'), ('question', 'nsubj', 'answers'), ('answering', 'acl', 'question'), ('well', 'advmod', 'written'), ('written', 'amod', 'cobb'), ('line', 'compound', 'scene'), ('scene', 'nmod', 'line'), ('key', 'amod', 'line'), ('whole', 'amod', 'line'), ('movie', 'compound', 'line'), ('line', 'compound', 'cobb'), ('cobb', 'dobj', 'answering'), ('mal', 'nsubj', 'answers'), ('answers', 'ccomp', 'makes'), ('questions', 'compound', 'oncethats'), ('oncethats', 'dobj', 'answers'), ('like', 'prep', 'oncethats'), ('movie', 'pobj', 'like'), ('much', 'amod', 'movies'), ('movies', 'dobj', 'answers'), ('potential', 'amod', 'movies'), ('making', 'acl', 'movies'), ('complex', 'amod', 'story'), ('story', 'dobj', 'making'), ('someone', 'nsubj', 'answer'), ('could', 'aux', 'answer'), ('answer', 'ccomp', 'answers'), ('one', 'nummod', 'sentence'), ('sentence', 'dobj', 'answer'), ('you', 'nsubj', 'waiting'), ('re', 'aux', 'waiting'), ('waiting', 'relcl', 'sentence'), ('line', 'compound', 'contents'), ('whole', 'amod', 'content'), ('content', 'compound', 'contents'), ('contents', 'nsubj', 'mean'), ('mean', 'parataxis', 'waiting'), ('movie', 'compound', 'series'), ('tv', 'compound', 'series'), ('series', 'nsubj', 'wellbesides'), ('managing', 'acl', 'series'), ('wellbesides', 'ccomp', 'mean'), ('greatness', 'compound', 'storyline'), ('storyline', 'compound', 'movie'), ('movie', 'dobj', 'wellbesides'), ('really', 'advmod', 'great'), ('great', 'amod', 'performances'), ('cast', 'amod', 'performances'), ('acting', 'amod', 'performances'), ('performances', 'dobj', 'answer'), ('also', 'advmod', 'great'), ('great', 'amod', 'award'), ('award', 'nsubj', 'winning'), ('winning', 'acl', 'performances'), ('cinematography', 'nsubj', 'pfister'), ('wally', 'advmod', 'pfister'), ('pfister', 'ccomp', 'winning'), ('great', 'amod', 'scores'), ('original', 'amod', 'scores'), ('scores', 'dobj', 'pfister'), ('hans', 'compound', 'effects'), ('zimmer', 'nmod', 'effects'), ('brilliant', 'amod', 'effects'), ('visual', 'amod', 'effects'), ('effects', 'nsubj', 'screenplay'), ('unique', 'amod', 'screenplay'), ('screenplay', 'conj', 'winning'), ('nearly', 'advmod', 'technical'), ('technical', 'amod', 'details'), ('details', 'dobj', 'screenplay'), ('great', 'advmod', 'gon')]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# [('wake', 'ROOT', 'wake'), ('good', 'amod', 'dream'), ('dream', 'dobj', 'wake'), ('feel', 'ccomp', 'wake'), ('reality', 'nsubj', 'attached'), ('harsh', 'amod', 'dream'), ('wake', 'nmod', 'dream'), ('bad', 'amod', 'dream'), ('dream', 'appos', 'reality'), ('sentimentally', 'advmod', 'attached'), ('attached', 'ccomp', 'feel'), ('beauty', 'compound', 'reality'), ('reality', 'dobj', 'attached'), ('long', 'amod', 'life'), ('life', 'nmod', 'reality'), ('good', 'amod', 'reality'), ('reality', 'npadvmod', 'attached'), ('dreams', 'nsubj', 'matter'), ('do', 'aux', 'matter'), ('nt', 'neg', 'matter'), ('matter', 'ccomp', 'wake')]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# [('inception', 'nsubj', 'entertaining'), ('might', 'aux', 'entertaining'), ('better', 'amod', 'movie'), ('movie', 'nsubj', 'entertaining'), ('would', 'aux', 'entertaining'), ('certainly', 'advmod', 'entertaining'), ('entertaining', 'ROOT', 'entertaining'), ('writerdirector', 'compound', 'nolan'), ('christopher', 'compound', 'nolan'), ('nolan', 'dobj', 'entertaining'), ('made', 'conj', 'entertaining'), ('premise', 'nmod', 'film'), ('complicated', 'amod', 'film'), ('film', 'nsubj', 'spend'), ('spend', 'ccomp', 'made'), ('entire', 'amod', 'time'), ('running', 'compound', 'time'), ('time', 'dobj', 'spend'), ('explaining', 'advcl', 'spend'), ('audienceseriously', 'advmod', 'exposition'), ('exposition', 'dobj', 'explaining'), ('never', 'neg', 'stops'), ('stops', 'ccomp', 'spend'), ('literally', 'advmod', 'moments'), ('moments', 'dep', 'entertaining'), ('action', 'compound', 'sequences'), ('sequences', 'dobj', 'moments'), ('one', 'nummod', 'character'), ('character', 'nsubj', 'pause'), ('would', 'aux', 'pause'), ('pause', 'conj', 'entertaining'), ('explain', 'xcomp', 'pause'), ('going', 'xcomp', 'explain'), ('another', 'det', 'course'), ('character', 'compound', 'course'), ('course', 'dobj', 'going'), ('hamfisted', 'conj', 'entertaining'), ('way', 'npadvmod', 'hamfisted'), ('explaining', 'advcl', 'hamfisted'), ('us', 'dative', 'explaining'), ('even', 'advmod', 'aggressive'), ('aggressive', 'amod', 'movie'), ('exposition', 'compound', 'movie'), ('movie', 'dobj', 'explaining'), ('never', 'neg', 'make'), ('make', 'ccomp', 'explaining'), ('lot', 'compound', 'sense'), ('sense', 'nsubj', 'result'), ('result', 'ccomp', 'make'), ('lot', 'npadvmod', 'result'), ('busyness', 'punct', 'entertaining'), ('oh', 'intj', 's'), ('there', 'expl', 's'), ('s', 'ROOT', 's'), ('always', 'advmod', 's'), ('plenty', 'amod', 'stuff'), ('stuff', 'attr', 's'), ('going', 'acl', 'stuff'), ('that', 'nsubj', 's'), ('s', 'ccomp', 'going'), ('nevertheless', 'advmod', 's'), ('pretty', 'advmod', 'boring'), ('boring', 'acomp', 's'), ('never', 'neg', 'clear'), ('clear', 'amod', 'fornolan'), ('busyness', 'compound', 'fornolan'), ('fornolan', 'nsubj', 'done'), ('done', 'relcl', 'stuff'), ('us', 'dobj', 'done'), ('hell', 'npadvmod', 'done'), ('came', 'xcomp', 's'), ('prestige', 'compound', 'clue'), ('clue', 'compound', 'movie'), ('movie', 'dobj', 'came'), ('even', 'advmod', 'coherent'), ('narratively', 'advmod', 'coherent'), ('coherent', 'amod', 'films'), ('films', 'nsubj', 'suffer'), ('like', 'prep', 'films'), ('dark', 'amod', 'knight'), ('knight', 'pobj', 'like'), ('suffer', 'conj', 's'), ('lack', 'compound', 'humor'), ('humor', 'nsubj', 'burden'), ('burden', 'compound', 'premises'), ('philosophical', 'amod', 'premises'), ('pondering', 'compound', 'premises'), ('premises', 'nsubj', 'support'), ('ca', 'aux', 'support'), ('nt', 'neg', 'support'), ('support', 'ccomp', 'suffer'), ('inception', 'compound', 'exception'), ('exception', 'dobj', 'support'), ('ha', 'intj', 'exception'), ('movie', 'compound', 'junk'), ('junk', 'appos', 'exception'), ('trying', 'acl', 'exception'), ('disguise', 'conj', 'support'), ('something', 'dobj', 'disguise'), ('important', 'amod', 'something'), ('significant', 'amod', 'fun'), ('much', 'amod', 'fun'), ('fun', 'dobj', 'support'), ('would', 'aux', 'content'), ('content', 'ccomp', 's'), ('junkgrade', 'dobj', 'content'), ('c', 'punct', 's')]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# dtype: int64

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
#The task provided a thorough opportunity to utilise numerous NLP approaches, such as data cleaning, POS tagging, parsing, and NER. The intricacy of language structures and entity recognition made parsing and NER very difficult. However, it was entertaining to watch the data transformation and analysis take place. The time allotted appeared appropriate for finishing the job, balancing exploration and implementation within a fair time schedule.
